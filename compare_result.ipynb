# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
from utils.plotting import *

# %%
# LOOKING FOR FOLDERS

# filter all folder name in rel_path = "/home/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" that contain "finetune_20251030-232939_model_20"

rel_path = "./results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000"
dir_path_seeds = []
for folder_name in os.listdir(rel_path):
    if "MLP_DC3_" in folder_name:
        dir_path_seeds.append(os.path.join(folder_name))

# print line by line dir_path_seeds, order by seeds
for path in dir_path_seeds:
    print(f"\"{path}\",")
# Out:
# "20260118-225115_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000",
# "20260118-225653_MLP_DC3_seed2_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260118-230024_MLP_DC3_seed2_nepochs1000_lr0.0001_trainsize7000",
# "20260118-230534_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260119-003209_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000",
# "20260118-233059_MLP_DC3_seed3_nepochs1000_lr0.00012_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260118-222424_MLP_DC3_seed0_nepochs1000_lr0.0001_trainsize7000",
# "20260118-233101_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260118-235225_MLP_DC3_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260118-235225_MLP_DC3_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300",
# "20260119-003210_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300",
# "20260118-223637_MLP_DC3_seed1_nepochs1000_lr0.0001_trainsize7000",
# "20260118-223717_MLP_DC3_seed0_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",
# "20260118-224813_MLP_DC3_seed1_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230",

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260118-225115_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_5d5de_row0_col0, #T_5d5de_row0_col1, #T_5d5de_row0_col2, #T_5d5de_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_5d5de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d5de_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_5d5de_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_5d5de_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_5d5de_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d5de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d5de_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_5d5de_row0_col1" class="data row0 col1" >-465.57%</td>
#       <td id="T_5d5de_row0_col2" class="data row0 col2" >2.20e-13</td>
#       <td id="T_5d5de_row0_col3" class="data row0 col3" >6.08e-03</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260118-235225_MLP_DC3_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_ec43c_row0_col0, #T_ec43c_row0_col1, #T_ec43c_row0_col2, #T_ec43c_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_ec43c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec43c_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_ec43c_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_ec43c_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_ec43c_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec43c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec43c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_ec43c_row0_col1" class="data row0 col1" >370.09%</td>
#       <td id="T_ec43c_row0_col2" class="data row0 col2" >3.29e-13</td>
#       <td id="T_ec43c_row0_col3" class="data row0 col3" >3.66e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260118-235225_MLP_DC3_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_e6f2b_row0_col0, #T_e6f2b_row0_col1, #T_e6f2b_row0_col2, #T_e6f2b_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_e6f2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6f2b_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_e6f2b_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_e6f2b_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_e6f2b_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6f2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6f2b_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_e6f2b_row0_col1" class="data row0 col1" >158.34%</td>
#       <td id="T_e6f2b_row0_col2" class="data row0 col2" >2.90e-13</td>
#       <td id="T_e6f2b_row0_col3" class="data row0 col3" >1.10e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-003209_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_b38ec_row0_col0, #T_b38ec_row0_col1, #T_b38ec_row0_col2, #T_b38ec_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_b38ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b38ec_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_b38ec_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_b38ec_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_b38ec_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b38ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b38ec_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_b38ec_row0_col1" class="data row0 col1" >798.45%</td>
#       <td id="T_b38ec_row0_col2" class="data row0 col2" >2.24e-13</td>
#       <td id="T_b38ec_row0_col3" class="data row0 col3" >5.30e-03</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-003210_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_e0a98_row0_col0, #T_e0a98_row0_col1, #T_e0a98_row0_col2, #T_e0a98_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_e0a98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0a98_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_e0a98_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_e0a98_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_e0a98_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0a98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0a98_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_e0a98_row0_col1" class="data row0 col1" >1244.53%</td>
#       <td id="T_e0a98_row0_col2" class="data row0 col2" >2.22e-13</td>
#       <td id="T_e0a98_row0_col3" class="data row0 col3" >1.18e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %% [markdown]
# seed 0, 0.0002
#
# seed 1, 0.0002 (bad)
#
# seed -1, 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable
