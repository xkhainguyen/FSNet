# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
from utils.plotting import *

# %%
# LOOKING FOR FOLDERS

# filter all folder name in rel_path = "/home/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" that contain "finetune_20251030-232939_model_20"

rel_path = "./results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000"
dir_path_seeds = []
for folder_name in os.listdir(rel_path):
    if "finetune_20260115-145229_sup_seedpen_model_630" in folder_name:
        dir_path_seeds.append(os.path.join(folder_name))

# print line by line dir_path_seeds, order by seeds
for path in dir_path_seeds:
    print(f"\"{path}\",")
# Out:
# "20260115-153755_MLP_FSNet_seed0_nepochs300_lr0.0002_trainsize7000_finetune_20260115-145229_sup_seedpen_model_630",
# "20260115-153756_MLP_FSNet_seed2_nepochs300_lr0.0002_trainsize7000_finetune_20260115-145229_sup_seedpen_model_630",
# "20260115-154949_MLP_FSNet_seed1_nepochs300_lr0.0002_trainsize7000_finetune_20260115-145229_sup_seedpen_model_630",
# "20260115-154950_MLP_FSNet_seed3_nepochs300_lr0.0002_trainsize7000_finetune_20260115-145229_sup_seedpen_model_630",

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260114-051731_MLP_penalty_seed1_nepochs1000_lr0.0001_trainsize7000"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_3a28f_row0_col0, #T_3a28f_row0_col1, #T_3a28f_row0_col2, #T_3a28f_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_3a28f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a28f_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_3a28f_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_3a28f_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_3a28f_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a28f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a28f_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_3a28f_row0_col1" class="data row0 col1" >313.05%</td>
#       <td id="T_3a28f_row0_col2" class="data row0 col2" >9.07e-01</td>
#       <td id="T_3a28f_row0_col3" class="data row0 col3" >3.70e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260115-001214_MLP_penalty_seed1_nepochs1000_lr0.0002_trainsize7000_finetune_20260114-152404_sup_seedseed0_model_50"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_af89c_row0_col0, #T_af89c_row0_col1, #T_af89c_row0_col2, #T_af89c_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_af89c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af89c_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_af89c_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_af89c_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_af89c_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af89c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af89c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_af89c_row0_col1" class="data row0 col1" >-579.49%</td>
#       <td id="T_af89c_row0_col2" class="data row0 col2" >1.26e+00</td>
#       <td id="T_af89c_row0_col3" class="data row0 col3" >1.13e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260115-002139_MLP_penalty_seed1_nepochs1000_lr0.0001_trainsize7000_finetune_20260114-152404_sup_seedseed0_model_50"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_c2c6e_row0_col0, #T_c2c6e_row0_col1, #T_c2c6e_row0_col2, #T_c2c6e_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_c2c6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2c6e_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_c2c6e_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_c2c6e_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_c2c6e_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2c6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2c6e_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_c2c6e_row0_col1" class="data row0 col1" >-590.09%</td>
#       <td id="T_c2c6e_row0_col2" class="data row0 col2" >9.80e-01</td>
#       <td id="T_c2c6e_row0_col3" class="data row0 col3" >1.02e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260115-002608_MLP_penalty_seed1_nepochs1000_lr5e-05_trainsize7000_finetune_20260114-152404_sup_seedseed0_model_50"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_b1307_row0_col0, #T_b1307_row0_col1, #T_b1307_row0_col2, #T_b1307_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_b1307">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1307_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_b1307_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_b1307_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_b1307_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1307_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1307_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_b1307_row0_col1" class="data row0 col1" >-577.49%</td>
#       <td id="T_b1307_row0_col2" class="data row0 col2" >8.61e-01</td>
#       <td id="T_b1307_row0_col3" class="data row0 col3" >1.04e-02</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260114-010901_MLP_FSNet_seed3_nepochs300_lr0.0002_trainsize7000_finetune_20260113-223104_model_trainsize7000/model"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260114-010901_MLP_FSNet_seed3_nepochs300_lr0.0002_trainsize7000_finetune_20260113-223104_model_trainsize7000/model/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260114-010901_MLP_FSNet_seed3_nepochs300_lr0.0002_trainsize7000_finetune_20260113-223104_model_trainsize7000/model/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# seed 0, 0.0002
#
# seed 1, 0.0002 (bad)
#
# seed -1, 0.0001
