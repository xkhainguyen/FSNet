# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
from utils.plotting import *

# %%
# LOOKING FOR FOLDERS

# filter all folder name in rel_path = "/home/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" that contain "finetune_20251030-232939_model_20"

rel_path = "./results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000"
dir_path_seeds = []
for folder_name in os.listdir(rel_path):
    if "20260116-173042" in folder_name and "FSNet" in folder_name:
        dir_path_seeds.append(os.path.join(folder_name))

# print line by line dir_path_seeds, order by seeds
for path in dir_path_seeds:
    print(f"\"{path}\",")
# Out:
# "20260116-180437_MLP_FSNet_seed2_nepochs300_lr0.0002_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260117-175720_MLP_FSNet_seed1_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260118-150337_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_990",
# "20260116-175133_MLP_FSNet_seed1_nepochs300_lr0.0002_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260118-150337_MLP_FSNet_seed2_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_990",
# "20260117-175809_MLP_FSNet_seed3_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260117-174228_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260116-173648_MLP_FSNet_seed0_nepochs300_lr0.0002_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260118-151724_MLP_FSNet_seed1_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_990",
# "20260117-174228_MLP_FSNet_seed2_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260116-181925_MLP_FSNet_seed3_nepochs300_lr0.0002_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430",
# "20260118-151812_MLP_FSNet_seed3_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_990",

# %% [markdown]
# "20260327-050238_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize800_subopt_3_0.0",
# "20260327-040558_MLP_sup_partial_seed0_nepochs1000_lr0.0005_trainsize7000_subopt_3_0.0",
# "20260326-234527_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize7000_subopt_3_0.0",
# "20260327-032828_MLP_sup_partial_seed0_nepochs1000_lr0.0005_trainsize800_subopt_3_0.0",
# "20260327-010758_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize800_subopt_3_0.0",
# "20260327-045910_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize7000_subopt_3_0.0",

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260327-123959_MLP_FSNet_seed3_nepochs300_lr0.0001_trainsize7000_finetune_20260327-094852_sup_seedpen_model_250"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_f150a_row0_col0, #T_f150a_row0_col1, #T_f150a_row0_col2, #T_f150a_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_f150a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f150a_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_f150a_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_f150a_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_f150a_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f150a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f150a_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_f150a_row0_col1" class="data row0 col1" >-2.84</td>
#       <td id="T_f150a_row0_col2" class="data row0 col2" >1.75e-05</td>
#       <td id="T_f150a_row0_col3" class="data row0 col3" >3.71e-07</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260505-093635_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-094852_sup_seedpen_model_250"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_4311d_row0_col0, #T_4311d_row0_col1, #T_4311d_row0_col2, #T_4311d_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_4311d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4311d_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_4311d_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_4311d_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_4311d_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4311d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4311d_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_4311d_row0_col1" class="data row0 col1" >-2.63</td>
#       <td id="T_4311d_row0_col2" class="data row0 col2" >1.99e-05</td>
#       <td id="T_4311d_row0_col3" class="data row0 col3" >3.73e-07</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260117-175720_MLP_FSNet_seed1_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_daa87_row0_col0, #T_daa87_row0_col1, #T_daa87_row0_col2, #T_daa87_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_daa87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_daa87_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_daa87_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_daa87_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_daa87_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daa87_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_daa87_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_daa87_row0_col1" class="data row0 col1" >-2.68</td>
#       <td id="T_daa87_row0_col2" class="data row0 col2" >1.43e-05</td>
#       <td id="T_daa87_row0_col3" class="data row0 col3" >7.28e-08</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260117-174228_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260116-173042_sup_seedpen_model_430"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_fe5a4_row0_col0, #T_fe5a4_row0_col1, #T_fe5a4_row0_col2, #T_fe5a4_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_fe5a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe5a4_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_fe5a4_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_fe5a4_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_fe5a4_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe5a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe5a4_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_fe5a4_row0_col1" class="data row0 col1" >-2.82</td>
#       <td id="T_fe5a4_row0_col2" class="data row0 col2" >2.17e-05</td>
#       <td id="T_fe5a4_row0_col3" class="data row0 col3" >1.81e-07</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# seed 0, 0.0002
#
# seed 1, 0.0002 (bad)
#
# seed -1, 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable
