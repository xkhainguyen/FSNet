# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
from utils.plotting import *

# %%
# LOOKING FOR FOLDERS

# filter all folder name in rel_path = "/home/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" that contain "finetune_20251030-232939_model_20"

rel_path = "./results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000"
dir_path_seeds = []
for folder_name in os.listdir(rel_path):
    if "_nepochs1000_lr0.0001_trainsize7000" in folder_name and "FS" in folder_name:
        dir_path_seeds.append(os.path.join(folder_name))

# print line by line dir_path_seeds, order by seeds
for path in dir_path_seeds:
    print(f"\"{path}\",")
# Out:
# "20260328-211058_MLP_FSNet_seed0_nepochs1000_lr0.0001_trainsize7000",
# "20260328-211058_MLP_FSNet_seed3_nepochs1000_lr0.0001_trainsize7000",
# "20260328-211058_MLP_FSNet_seed1_nepochs1000_lr0.0001_trainsize7000",
# "20260328-211058_MLP_FSNet_seed2_nepochs1000_lr0.0001_trainsize7000",

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260118-180755_MLP_adaptive_penalty_seed3_nepochs1000_lr0.0001_trainsize7000"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_9a443_row0_col0, #T_9a443_row0_col1, #T_9a443_row0_col2, #T_9a443_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_9a443">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a443_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_9a443_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_9a443_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_9a443_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a443_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a443_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_9a443_row0_col1" class="data row0 col1" >17.20</td>
#       <td id="T_9a443_row0_col2" class="data row0 col2" >7.61e-01</td>
#       <td id="T_9a443_row0_col3" class="data row0 col3" >3.25e-04</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-143633_MLP_adaptive_penalty_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260116-022657_sup_seedpen_model_200"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-143633_MLP_adaptive_penalty_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260116-022657_sup_seedpen_model_200/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-143633_MLP_adaptive_penalty_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260116-022657_sup_seedpen_model_200/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results = load_results(path)
# ---> 10 show_table(results)
#      11 results['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-142751_MLP_adaptive_penalty_seed3_nepochs1000_lr0.00015_trainsize7000_finetune_20260116-022657_sup_seedpen_model_940"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_6af19_row0_col0, #T_6af19_row0_col1, #T_6af19_row0_col2, #T_6af19_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_6af19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6af19_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_6af19_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_6af19_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_6af19_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6af19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6af19_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_6af19_row0_col1" class="data row0 col1" >4.73</td>
#       <td id="T_6af19_row0_col2" class="data row0 col2" >8.54e-01</td>
#       <td id="T_6af19_row0_col3" class="data row0 col3" >5.03e-03</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260118-180454_MLP_adaptive_penalty_seed2_nepochs1000_lr0.0001_trainsize7000_finetune_20260116-022657_sup_seedpen_model_940"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_51500_row0_col0, #T_51500_row0_col1, #T_51500_row0_col2, #T_51500_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_51500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51500_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_51500_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_51500_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_51500_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51500_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_51500_row0_col1" class="data row0 col1" >15.18</td>
#       <td id="T_51500_row0_col2" class="data row0 col2" >7.59e-01</td>
#       <td id="T_51500_row0_col3" class="data row0 col3" >5.90e-04</td>
#     </tr>
#   </tbody>
# </table>
# 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# seed 0, 0.0002
#
# seed 1, 0.0002 (bad)
#
# seed -1, 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
#     561 def show_table(results, batch_size=512):
# --> 562     batch_comparison = results['test_results']['batch_size_comparison']
#     563     # Create a more readable DataFrame by expanding the metrics
#     564     readable_data = []
#
# TypeError: 'NoneType' object is not subscriptable
