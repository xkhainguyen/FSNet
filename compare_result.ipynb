# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import os
from utils.plotting import *

# %%
# LOOKING FOR FOLDERS

# filter all folder name in rel_path = "/home/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" that contain "finetune_20251030-232939_model_20"

rel_path = "./results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000"
dir_path_seeds = []
for folder_name in os.listdir(rel_path):
    if "MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_" in folder_name and "20260506" in folder_name:
        dir_path_seeds.append(os.path.join(folder_name))

# print line by line dir_path_seeds, order by seeds
for path in dir_path_seeds:
    print(f"\"{path}\",")
# Out:
# "20260506-032718_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_900",
# "20260506-031229_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_300",
# "20260506-031006_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_100",
# "20260506-031704_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_500",
# "20260506-032141_MLP_FSNet_seed0_nepochs300_lr0.0001_trainsize7000_finetune_20260327-092838_sup_seedpen_model_700",

# %% [markdown]
# "20260327-050238_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize800_subopt_3_0.0",
# "20260327-040558_MLP_sup_partial_seed0_nepochs1000_lr0.0005_trainsize7000_subopt_3_0.0",
# "20260326-234527_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize7000_subopt_3_0.0",
# "20260327-032828_MLP_sup_partial_seed0_nepochs1000_lr0.0005_trainsize800_subopt_3_0.0",
# "20260327-010758_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize800_subopt_3_0.0",
# "20260327-045910_MLP_sup_pen_seed0_nepochs1000_lr0.0001_trainsize7000_subopt_3_0.0",

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260505-151430_MLP_penalty_seed0_nepochs1000_lr8e-05_trainsize7000_finetune_20260115-184556_sup_seedpen_model_150"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_aa8e5_row0_col0, #T_aa8e5_row0_col1, #T_aa8e5_row0_col2, #T_aa8e5_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_aa8e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa8e5_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_aa8e5_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_aa8e5_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_aa8e5_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa8e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa8e5_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_aa8e5_row0_col1" class="data row0 col1" >-0.14</td>
#       <td id="T_aa8e5_row0_col2" class="data row0 col2" >7.83e-01</td>
# ...

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260505-151744_MLP_penalty_seed1_nepochs1000_lr8e-05_trainsize7000_finetune_20260115-184556_sup_seedpen_model_150"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results = load_results(path)
show_table(results)
results['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_0fefe_row0_col0, #T_0fefe_row0_col1, #T_0fefe_row0_col2, #T_0fefe_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_0fefe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fefe_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_0fefe_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_0fefe_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_0fefe_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fefe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fefe_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_0fefe_row0_col1" class="data row0 col1" >-0.10</td>
#       <td id="T_0fefe_row0_col2" class="data row0 col2" >7.82e-01</td>
# ...

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260505-152057_MLP_penalty_seed2_nepochs1000_lr8e-05_trainsize7000_finetune_20260115-184556_sup_seedpen_model_150"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_f766c_row0_col0, #T_f766c_row0_col1, #T_f766c_row0_col2, #T_f766c_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_f766c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f766c_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_f766c_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_f766c_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_f766c_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f766c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f766c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_f766c_row0_col1" class="data row0 col1" >-0.10</td>
#       <td id="T_f766c_row0_col2" class="data row0 col2" >8.33e-01</td>
# ...

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260505-152414_MLP_penalty_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260115-184556_sup_seedpen_model_150"

path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# <style type="text/css">
# #T_5686d_row0_col0, #T_5686d_row0_col1, #T_5686d_row0_col2, #T_5686d_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_5686d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5686d_level0_col0" class="col_heading level0 col0" >Batch Size</th>
#       <th id="T_5686d_level0_col1" class="col_heading level0 col1" >Opt Gap Mean</th>
#       <th id="T_5686d_level0_col2" class="col_heading level0 col2" >Eq Violation Mean</th>
#       <th id="T_5686d_level0_col3" class="col_heading level0 col3" >Ineq Violation Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5686d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5686d_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_5686d_row0_col1" class="data row0 col1" >0.01</td>
#       <td id="T_5686d_row0_col2" class="data row0 col2" >8.12e-01</td>
# ...

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-011636_MLP_DC3_seed3_nepochs1000_lr0.0001_trainsize7000_finetune_20260118-184700_sup_seedpartial_model_230/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
# ...

# %% [markdown]
# seed 0, 0.0002
#
# seed 1, 0.0002 (bad)
#
# seed -1, 0.0001

# %%
from pathlib import Path

base = Path.cwd()

filename = "20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300"
    
path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"

results2 = load_results(path)
show_table(results2)
results2['config']['FSNet']['lr']
# Out:
# Error loading /orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl: [Errno 2] No such file or directory: '/orcd/home/002/khain/FSNet/results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000/20260119-004421_MLP_DC3_seed3_nepochs1000_lr8e-05_trainsize7000_finetune_20260118-234011_sup_seedpartial_model_300/results.pkl'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 10
#       7 path = base / "results/nonsmooth_nonconvex/socp/SOCPProblem-100-50-50-10000" / filename / "results.pkl"
#       9 results2 = load_results(path)
# ---> 10 show_table(results2)
#      11 results2['config']['FSNet']['lr']
#
# File /orcd/home/002/khain/FSNet/utils/plotting.py:562, in show_table(results, batch_size)
# ...
